# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("apartments.csv")
data['price'] = data['price'].str.replace(' ', '').astype(float)

# %%
data
# Out:
#                                                   title  \
# 0       3 Bedroom Apartment / Flat to rent in Riverside
# 1      3 Bedroom Apartment / Flat to rent in Kileleshwa
# 2           3 Bedroom Apartment / Flat to rent in Nyali
# 3       3 Bedroom Apartment / Flat to rent in Lavington
# 4      1 Bedroom Apartment / Flat to rent in Kileleshwa
# ...                                                 ...
# 2515     3 Bedroom Apartment / Flat to rent in Kilimani
# 2516        3 Bedroom Apartment / Flat to rent in Nyali
# 2517  2 Bedroom Apartment / Flat to rent in Spring V...
# 2518     4 Bedroom Apartment / Flat to rent in Muthaiga
# 2519    2 Bedroom Apartment / Flat to rent in Westlands
#
#                                                location  bedrooms  bathrooms  \
# 0              Riverside Dr Nairobi, Riverside, Nairobi         3          3
# 1                                   Kileleshwa, Nairobi         3          4
# 2                      Links Rd Mombasa, Nyali, Mombasa         3          2
# 3                Near Valley Arcade, Lavington, Nairobi         3          3
# 4                                   Kileleshwa, Nairobi         1          1
# ...                                                 ...       ...        ...
# 2515                                  Kilimani, Nairobi         3          3
# 2516                                                NaN         3          2
# 2517  Grevillea Grove Spring Valley, Spring Valley, ...         2          3
# 2518                                  Muthaiga, Nairobi         4          5
# 2519                                 Westlands, Nairobi         2          2
#
#          price       rate
# 0     200000.0  Per Month
# 1      70000.0  Per Month
# 2      38000.0  Per Month
# 3      80000.0  Per Month
# 4     110000.0  Per Month
# ...        ...        ...
# 2515   75000.0  Per Month
# 2516   45000.0  Per Month
# 2517   65000.0  Per Month
# 2518  300000.0  Per Month
# 2519  100000.0  Per Month
#
# [2520 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2520 entries, 0 to 2519
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      2520 non-null   object
#  1   location   2144 non-null   object
#  2   bedrooms   2520 non-null   int64
#  3   bathrooms  2520 non-null   int64
#  4   price      2520 non-null   float64
#  5   rate       2520 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 118.3+ KB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2144 entries, 0 to 2519
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      2144 non-null   object
#  1   location   2144 non-null   object
#  2   bedrooms   2144 non-null   int64
#  3   bathrooms  2144 non-null   int64
#  4   price      2144 non-null   float64
#  5   rate       2144 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 117.2+ KB

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['price'], axis=1)
y = data['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#                                                   title  \
# 893        3 Bedroom Apartment / Flat to rent in Kikuyu
# 250   2 Bedroom Apartment / Flat to rent in Spring V...
# 782   4 Bedroom Apartment / Flat to rent in Kahawa W...
# 1593    4 Bedroom Apartment / Flat to rent in Westlands
# 197      4 Bedroom Apartment / Flat to rent in Muthaiga
# ...                                                 ...
# 279   4 Bedroom Apartment / Flat to rent in Kahawa W...
# 174      2 Bedroom Apartment / Flat to rent in Kilimani
# 1118  4 Bedroom Apartment / Flat to rent in Kahawa W...
# 226    2 Bedroom Apartment / Flat to rent in Kileleshwa
# 734     2 Bedroom Apartment / Flat to rent in Westlands
#
#                                                location  bedrooms  bathrooms  \
# 893         Kikuyu Town Bus park Kikuyu, Kikuyu, Kikuyu         3          3
# 250   Grevillea Grove Spring Valley, Spring Valley, ...         2          3
# 782           Thika Rd Nairobi, Kahawa Wendani, Nairobi         4          2
# 1593                                 Westlands, Nairobi         4          2
# 197                                   Muthaiga, Nairobi         4          5
# ...                                                 ...       ...        ...
# 279           Thika Rd Nairobi, Kahawa Wendani, Nairobi         4          2
# 174                                   Kilimani, Nairobi         2          3
# 1118          Thika Rd Nairobi, Kahawa Wendani, Nairobi         4          2
# 226             Kileleshwa Nairobi, Kileleshwa, Nairobi         2          2
# 734                                  Westlands, Nairobi         2          2
#
#            rate     price
# 893   Per Month   55000.0
# 250   Per Month   65000.0
# 782   Per Month   57750.0
# 1593  Per Month  165000.0
# 197   Per Month  300000.0
# ...         ...       ...
# 279   Per Month   57750.0
# 174   Per Month   65000.0
# 1118  Per Month   57750.0
# 226   Per Month   55000.0
# 734   Per Month  100000.0
#
# [1715 rows x 6 columns]

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: >]], dtype=object)

# %%
train_data = train_data.drop('title', axis=1)
train_data = train_data.drop('rate', axis=1)
plt.figure(figsize=(12,6))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
#   Cell In[155], line 1
#     train-data = train_data.drop('title', axis=1)
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
train_data['bedrooms'] = np.log(train_data['bedrooms'] + 1)
train_data['bathrooms'] = np.log(train_data['bathrooms'] + 1)

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: >]], dtype=object)

# %%
train_data = train_data.join(pd.get_dummies(train_data.location)).drop(['location'], axis=1)
# Out:
# ------------------------------------------------------
# AttributeError       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_940\3548914677.py in ?()
# ----> 1 train_data = train_data.join(pd.get_dummies(train_data.location)).drop(['location'], axis=1)
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'location'

# %%
train_data
# Out:
#                                                   title  bedrooms  bathrooms  \
# 893        3 Bedroom Apartment / Flat to rent in Kikuyu  0.869742   0.869742
# 250   2 Bedroom Apartment / Flat to rent in Spring V...  0.741276   0.869742
# 782   4 Bedroom Apartment / Flat to rent in Kahawa W...  0.959135   0.741276
# 1593    4 Bedroom Apartment / Flat to rent in Westlands  0.959135   0.741276
# 197      4 Bedroom Apartment / Flat to rent in Muthaiga  0.959135   1.026672
# ...                                                 ...       ...        ...
# 279   4 Bedroom Apartment / Flat to rent in Kahawa W...  0.959135   0.741276
# 174      2 Bedroom Apartment / Flat to rent in Kilimani  0.741276   0.869742
# 1118  4 Bedroom Apartment / Flat to rent in Kahawa W...  0.959135   0.741276
# 226    2 Bedroom Apartment / Flat to rent in Kileleshwa  0.741276   0.741276
# 734     2 Bedroom Apartment / Flat to rent in Westlands  0.741276   0.741276
#
#            rate     price  \
# 893   Per Month   55000.0
# 250   Per Month   65000.0
# 782   Per Month   57750.0
# 1593  Per Month  165000.0
# 197   Per Month  300000.0
# ...         ...       ...
# 279   Per Month   57750.0
# 174   Per Month   65000.0
# 1118  Per Month   57750.0
# 226   Per Month   55000.0
# 734   Per Month  100000.0
#
#       Grevillea Grove Spring Valley, Spring Valley, Nairobi  \
# 893                                               False
# 250                                                True
# 782                                               False
# 1593                                              False
# 197                                               False
# ...                                                 ...
# 279                                               False
# 174                                               False
# 1118                                              False
# 226                                               False
# 734                                               False
#
#       Jabavu court, Kilimani, Nairobi  \
# 893                             False
# 250                             False
# 782                             False
# 1593                            False
# 197                             False
# ...                               ...
# 279                             False
# 174                             False
# 1118                            False
# 226                             False
# 734                             False
#
#       Kikuyu Town Bus park Kikuyu, Kikuyu, Kikuyu  \
# 893                                          True
# 250                                         False
# 782                                         False
# 1593                                        False
# 197                                         False
# ...                                           ...
# 279                                         False
# 174                                         False
# 1118                                        False
# 226                                         False
# 734                                         False
#
#       Kileleshwa Nairobi, Kileleshwa, Nairobi  Kileleshwa, Nairobi  ...  \
# 893                                     False                False  ...
# 250                                     False                False  ...
# 782                                     False                False  ...
# 1593                                    False                False  ...
# 197                                     False                False  ...
# ...                                       ...                  ...  ...
# 279                                     False                False  ...
# 174                                     False                False  ...
# 1118                                    False                False  ...
# 226                                      True                False  ...
# 734                                     False                False  ...
#
#       Muthaiga, Nairobi  Near Valley Arcade, Lavington, Nairobi  \
# 893               False                                   False
# 250               False                                   False
# 782               False                                   False
# 1593              False                                   False
# 197                True                                   False
# ...                 ...                                     ...
# 279               False                                   False
# 174               False                                   False
# 1118              False                                   False
# 226               False                                   False
# 734               False                                   False
#
#       Nyali, Mombasa  Off Othaya road, Lavington, Nairobi  \
# 893            False                                False
# 250            False                                False
# 782            False                                False
# 1593           False                                False
# 197            False                                False
# ...              ...                                  ...
# 279            False                                False
# 174            False                                False
# 1118           False                                False
# 226            False                                False
# 734            False                                False
#
#       Riverside Dr Nairobi, Riverside, Nairobi  Shanzu, Mombasa  \
# 893                                      False            False
# 250                                      False            False
# 782                                      False            False
# 1593                                     False            False
# 197                                      False            False
# ...                                        ...              ...
# 279                                      False            False
# 174                                      False            False
# 1118                                     False            False
# 226                                      False            False
# 734                                      False            False
#
#       Thika Rd Nairobi, Kahawa Wendani, Nairobi  \
# 893                                       False
# 250                                       False
# 782                                        True
# 1593                                      False
# 197                                       False
# ...                                         ...
# 279                                        True
# 174                                       False
# 1118                                       True
# 226                                       False
# 734                                       False
#
#       Vihiga road, Kileleshwa, Nairobi  \
# 893                              False
# 250                              False
# 782                              False
# 1593                             False
# 197                              False
# ...                                ...
# 279                              False
# 174                              False
# 1118                             False
# 226                              False
# 734                              False
#
#       Westlands downtown, Westlands, Nairobi  Westlands, Nairobi
# 893                                    False               False
# 250                                    False               False
# 782                                    False               False
# 1593                                   False                True
# 197                                    False               False
# ...                                      ...                 ...
# 279                                    False               False
# 174                                    False               False
# 1118                                   False               False
# 226                                    False               False
# 734                                    False                True
#
# [1715 rows x 22 columns]

# %%
plt.figure(figsize=(12,6))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
# ------------------------------------------------------
# ValueError           Traceback (most recent call last)
# Cell In[120], line 2
#       1 plt.figure(figsize=(12,6))
# ----> 2 sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11022, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11020 cols = data.columns
#   11021 idx = cols.copy()
# > 11022 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11024 if method == "pearson":
#   11025     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1693, in BlockManager.as_array(self, dtype, copy, na_value)
#    1691         arr.flags.writeable = False
#    1692 else:
# -> 1693     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1694     # The underlying data was copied within _interleave, so no need
#    1695     # to further copy if copy=True or setting na_value
#    1697 if na_value is lib.no_default:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1752, in BlockManager._interleave(self, dtype, na_value)
#    1750     else:
#    1751         arr = blk.get_values(dtype)
# -> 1752     result[rl.indexer] = arr
#    1753     itemmask[rl.indexer] = 1
#    1755 if not itemmask.all():
#
# ValueError: could not convert string to float: '3 Bedroom Apartment / Flat to rent in Kikuyu'
